# %% [markdown]
# DISCOUNT TABLES

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleaneddiscount
(
    discount_id string, discount_code string, discount_name string, 
    discount_type string, discount_value double, min_purchase_amount double, 
    max_discount_amount double, valid_from date, ingest_ts timestamp
)

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleaneddiscount
(
    discount_id string, discount_code string, discount_name string, 
    discount_type string, discount_value double, min_purchase_amount double, 
    max_discount_amount double, valid_from date, ingest_ts timestamp
)

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleaneddiscount
(
    discount_id string, discount_code string, discount_name string, 
    discount_type string, discount_value double, min_purchase_amount double, 
    max_discount_amount double, valid_from date, ingest_ts timestamp
)

# %% [markdown]
# SALES TABLE

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedsales
(
    sale_id INTEGER , product string, category string, 
    quantity INTEGER , price double , 
    sale_date date , region string, 
    ingest_ts timestamp
);

# %% [markdown]
# CUSTOMER TABLE

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_dev.silver_dev.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_qa.silver_qa.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

# %%
# %sql
CREATE OR REPLACE TABLE saleslake_prd.silver_prd.cleanedcustomer
(
    customer_id int , customer_name string, email string, 
    phone string , address string , 
    city string , state string, 
    country string,zip_code string,
    segment string,
    ingest_ts timestamp
);

# %% [markdown]
# VOLUME CREATION

# %%
# %sql
CREATE VOLUME IF NOT EXISTS saleslake_dev.silver_dev.vol_saleslake_src_files_dev;

CREATE VOLUME IF NOT EXISTS saleslake_qa.silver_qa.vol_saleslake_src_files_qa;

CREATE VOLUME IF NOT EXISTS saleslake_prd.silver_prd.vol_saleslake_src_files_prd;

# %% [markdown]
# CUSTOMER ----> DIR

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/silver_dev/vol_saleslake_src_files_dev/daily_customer/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/silver_qa/vol_saleslake_src_files_qa/daily_customer/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/silver_prd/vol_saleslake_src_files_prd/daily_customer/")

# %% [markdown]
# Discount-->DIR

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/silver_dev/vol_saleslake_src_files_dev/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/silver_qa/vol_saleslake_src_files_qa/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/silver_prd/vol_saleslake_src_files_prd/daily_discount/")

# %% [markdown]
# SALES---> DIRC

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/silver_dev/vol_saleslake_src_files_dev/daily_sales/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/silver_qa/vol_saleslake_src_files_qa/daily_sales/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/silver_prd/vol_saleslake_src_files_prd/daily_sales/")

# %% [markdown]
# DISCOUNT --> DIR

# %%
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/silver_dev/vol_saleslake_src_files_dev/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/silver_qa/vol_saleslake_src_files_qa/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/silver_prd/vol_saleslake_src_files_prd/daily_discount/")

# %%
# %sql
DROP TABLE IF EXISTS saleslake_dev.silver_dev.cleaned

# %%
# %sql
CREATE OR REPLACE TABLE  saleslake_dev.silver_dev.cleanedInvoice 
 (
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/dev/Delta Tables/silver/Invoice";

# %%
# %sql
CREATE TABLE IF NOT EXISTS saleslake_qa.silver_qa.cleanedInvoice 
(
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/qa/Delta Tables/silver/Invoice";

# %%
# %sql
CREATE TABLE IF NOT EXISTS saleslake_prd.silver_prd.cleanedInvoice 
(
  invoice_id       STRING       NOT NULL,
  invoice_number   STRING      ,
  customer_id      BIGINT,
  invoice_date     DATE,
  due_date         DATE,
  subtotal_amount  DECIMAL(18,2),
  discount_code    STRING,
  discount_amount  DECIMAL(18,2),
  tax_amount       DECIMAL(18,2),
  total_amount     DECIMAL(18,2),
  payment_status   STRING,
  payment_method   STRING,
  payment_date     DATE,
  currency         STRING,
  region           STRING,
  store_id         STRING,
  channel          STRING,
  created_by       STRING,
  ingest_ts        TIMESTAMP    NOT NULL
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/prd/Delta Tables/silver/Invoice";
