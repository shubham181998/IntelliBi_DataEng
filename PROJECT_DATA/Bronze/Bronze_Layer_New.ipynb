-- %%
CREATE OR REPLACE TABLE intellibi_catalog.intellibi_bronze.df_monthlysales_bronze
(
    sale_id string, product string, category string,  quantity string,  price string, sale_date string, region string, ingest_ts TIMESTAMP
)

-- %%
describe intellibi_catalog.intellibi_bronze.df_monthlysales_bronze

-- %%
SELECT * FROM intellibi_catalog.intellibi_bronze.df_monthlySales_bronze;
