-- %%
COPY INTO intellibi_catalog.intellibi_bronze.df_monthlySales_bronze
FROM (SELECT sale_id, product, category,  quantity,  price, sale_date, region,current_timestamp() AS ingest_ts
FROM '/Volumes/intellibi_catalog/intellibi_data_files/files_added_csv_json')
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true')
COPY_OPTIONS ('mergeSchema' = 'false')

-- %%
--CREATE SCHEMA intellibi_catalog.intellibi_Bronze;
--CREATE SCHEMA intellibi_catalog.intellibi_Silver;
--CREATE SCHEMA intellibi_catalog.intellibi_Gold;
