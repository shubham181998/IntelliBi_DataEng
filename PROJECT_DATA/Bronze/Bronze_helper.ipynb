-- %%
CREATE CATALOG IF NOT EXISTS saleslake_dev;

CREATE CATALOG IF NOT EXISTS saleslake_qa;

CREATE CATALOG IF NOT EXISTS saleslake_prd;

-- %%
CREATE SCHEMA IF NOT EXISTS saleslake_dev.bronze_dev;

CREATE SCHEMA IF NOT EXISTS saleslake_dev.silver_dev;

CREATE SCHEMA IF NOT EXISTS saleslake_dev.gold_dev;

CREATE SCHEMA IF NOT EXISTS saleslake_qa.bronze_qa;

CREATE SCHEMA IF NOT EXISTS saleslake_qa.silver_qa;

CREATE SCHEMA IF NOT EXISTS saleslake_qa.gold_qa;

CREATE SCHEMA IF NOT EXISTS saleslake_prd.bronze_prd;

CREATE SCHEMA IF NOT EXISTS saleslake_prd.silver_prd;

CREATE SCHEMA IF NOT EXISTS saleslake_prd.gold_prd;

-- %%
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_src_files_dev;

CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_src_files_qa;

CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_src_files_prd;

-- %%
%python
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_customer/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_customer/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/daily_customer/")

-- %%
%python
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_sales/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_sales/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/daily_sales/")

-- %% [markdown]
-- RAW CUSTOMER TABLE

-- %%
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawCustomer

(

    customer_id string , customer_name string, email string, 

    phone string , address string , 

    city string , state string, 

    country string,zip_code string,

    segment string,

    ingest_ts timestamp

);

-- %%
CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawCustomer

(

    customer_id string , customer_name string, email string, 

    phone string , address string , 

    city string , state string, 

    country string,zip_code string,

    segment string,

    ingest_ts timestamp

);

-- %%
CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawCustomer

(

    customer_id string , customer_name string, email string, 

    phone string , address string , 

    city string , state string, 

    country string,zip_code string,

    segment string,

    ingest_ts timestamp

);

-- %% [markdown]
-- Discount---> Dir

-- %%
%python
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_src_files_dev/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_src_files_qa/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_src_files_prd/daily_discount/")

-- %%
CREATE VOLUME IF NOT EXISTS saleslake_dev.bronze_dev.vol_saleslake_archive_files_dev;

CREATE VOLUME IF NOT EXISTS saleslake_qa.bronze_qa.vol_saleslake_archive_files_qa;

CREATE VOLUME IF NOT EXISTS saleslake_prd.bronze_prd.vol_saleslake_archive_files_prd;

-- %%
%python
dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_dev/bronze_dev/vol_saleslake_archive_files_dev/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_qa/bronze_qa/vol_saleslake_archive_files_qa/daily_discount/")

dbutils.fs.mkdirs("dbfs:/Volumes/saleslake_prd/bronze_prd/vol_saleslake_archive_files_prd/daily_discount/")

-- %% [markdown]
-- RAW SALES TABLE

-- %%
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawsales

(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

-- %%
CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawsales

(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

-- %%
CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawprd

(
    sale_id string , product string, category string, 
    quantity string , price string , 
    sale_date string , region string, 
    ingest_ts timestamp
);

-- %% [markdown]
-- DISCOUNT TABLES

-- %%
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING,ingest_ts timestamp

);

-- %%
CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING,ingest_ts timestamp

);

-- %%
CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawDiscount
(

    discount_id STRING,discount_code STRING ,discount_name STRING,discount_type STRING, discount_value STRING,min_purchase_amount STRING,
    max_discount_amount STRING ,valid_from STRING,valid_to STRING ,applicable_segment STRING,applicable_category STRING,usage_limit_per_customer STRING,total_usage_limit STRING,is_active STRING,created_date STRING,ingest_ts timestamp

);

-- %% [markdown]
-- INVOICE TABLES

-- %%
DROP TABLE IF EXISTS saleslake_dev.bronze_dev.rawInvoice;

-- %%
CREATE OR REPLACE TABLE saleslake_dev.bronze_dev.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/dev/Delta Tables/bronze/Invoice/";

-- %%
CREATE OR REPLACE TABLE saleslake_qa.bronze_qa.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/qa/Delta Tables/bronze/Invoice/";

-- %%
CREATE OR REPLACE TABLE saleslake_prd.bronze_prd.rawInvoice
(
    invoice_id STRING,invoice_number STRING,customer_id STRING,invoice_date STRING,
    due_date STRING,subtotal_amount STRING,discount_code STRING, discount_amount STRING,tax_amount STRING,total_amount STRING,payment_status STRING,payment_method STRING,payment_date STRING,currency STRING,region STRING,store_id STRING, channel STRING,created_by STRING,
    ingest_ts timestamp
)
USING DELTA
LOCATION "s3://saleslake-748005667258-eu-north-1-an-sa/SalesLake/prd/Delta Tables/bronze/Invoice/";
